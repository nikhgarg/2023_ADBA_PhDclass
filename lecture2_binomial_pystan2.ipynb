# %%
import pystan

import nest_asyncio # https://pystan.readthedocs.io/en/latest/faq.html
nest_asyncio.apply()

# %%
# reload packages from notebook whenever needed
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

import arviz as az # For visualization and loo
import seaborn as sns

# %% [markdown]
# # Code by hand

# %%
data = {'N': 100, 'y': 50} #number of trials, number of successes

# %%
def p_data_given_theta(theta, data):
    return theta**data['y'] * (1-theta)**(data['N']-data['y'])

from scipy.stats import beta
def p_theta(theta):
    # beta(1, 1) prior
    return beta.pdf(theta, 1, 1)

def p_data(data, possible_theta_values=np.linspace(0, 1, 1000)):
    """
    This function is the marginal likelihood of the data.
    It is the integral of the likelihood function over possible values of theta, weighted by the prior.
    """
    unweighted_integral = np.sum([p_data_given_theta(theta, data) * p_theta(theta) for theta in possible_theta_values])
    integral = unweighted_integral / np.sum([p_theta(theta) for theta in possible_theta_values])
    return integral

# %%
possible_theta_values = np.linspace(0, 1, 1000)

denominator = p_data(data, possible_theta_values)
p_theta_given_data = [p_data_given_theta(theta, data) * p_theta(theta) / denominator 
                      for theta in possible_theta_values]

plt.plot(possible_theta_values, p_theta_given_data)

# %% [markdown]
# # Using Stan to fit a binomial model

# %%
stan_folder = 'stan_code/'
stan_file = stan_folder + 'binom.stan'
with open(stan_file) as file:
    model_code = file.read()
print(model_code)
# Out:
# // Binomial model with beta(1,1,) prior
# data {
#   int<lower=0> N;
#   int<lower=0> y;
# }
# parameters {
#   real<lower=0,upper=1> theta;
# }
# model {
#   theta ~ beta(1,1);
#   y ~ binomial(N,theta);
# }

# %%
stan_data = {'N': 100, 'y': 50} #number of trials, number of successes

# %%
model_code
# Out:
# '// Binomial model with beta(1,1,) prior\ndata {\n  int<lower=0> N;\n  int<lower=0> y;\n}\nparameters {\n  real<lower=0,upper=1> theta;\n}\nmodel {\n  theta ~ beta(1,1);\n  y ~ binomial(N,theta);\n}\n'

# %%
sm = pystan.StanModel(model_code=model_code, verbose = True, extra_compile_args= ["-flto"]) #flto = link time optimization I think for RAM issues?
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_a05259dcade68de9675d2ad9b1145f54 NOW.
# INFO:pystan:OS: linux, Python: 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 15:55:03)
# [GCC 10.4.0], Cython 0.29.33
# Compiling /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.pyx because it changed.
# [1/1] Cythonizing /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.pyx
# INFO:root:building 'stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374' extension
# INFO:root:creating /tmp/pystan_ypsd1oot/tmp
# INFO:root:creating /tmp/pystan_ypsd1oot/tmp/pystan_ypsd1oot
# INFO:root:/home/nkgarg/miniconda3/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/nkgarg/miniconda3/envs/ractest2/include -fPIC -O2 -isystem /home/nkgarg/miniconda3/envs/ractest2/include -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/nkgarg/miniconda3/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/nkgarg/miniconda3/include -fPIC -DBOOST_RESULT_OF_USE_TR1 -DBOOST_NO_DECLTYPE -DBOOST_DISABLE_ASSERTS -I/tmp/pystan_ypsd1oot -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/src -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3 -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0 -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/sundials_4.1.0/include -I/home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/numpy/core/include -I/home/nkgarg/miniconda3/envs/ractest2/include/python3.9 -c /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp -o /tmp/pystan_ypsd1oot/tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.o -O2 -ftemplate-depth-256 -Wno-unused-function -Wno-uninitialized -std=c++1y -flto
# In file included from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp:837:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# In file included from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_cholesky_factor.hpp:6,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_cholesky_factor_corr.hpp:5,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:52,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/py_var_context.hpp:12,
#                  from /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp:846:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_lower_triangular.hpp: In function 'bool stan::math::is_lower_triangular(const Eigen::Matrix<LhsScalar, -1, -1, 0>&)':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_lower_triangular.hpp:25:34: warning: 'std::pointer_to_unary_function<_Arg, _Result> std::ptr_fun(_Result (*)(_Arg)) [with _Arg = double; _Result = double]' is deprecated: use 'std::function' instead [-Wdeprecated-declarations]
#    25 |   return y.unaryExpr(std::ptr_fun(internal::notNan))
#       |                      ~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# In file included from /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/string:48,
#                  from /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/locale_classes.h:40,
#                  from /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/ios_base.h:41,
#                  from /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/ios:42,
#                  from /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp:815:
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:1126:5: note: declared here
#  1126 |     ptr_fun(_Result (*__x)(_Arg))
#       |     ^~~~~~~
# In file included from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_log.hpp:5,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:336:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_lpmf.hpp: In function 'typename stan::return_type<T_x, T_alpha, T_beta>::type stan::math::poisson_log_glm_lpmf(const T_y&, const T_x&, const T_alpha&, const T_beta&)':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_lpmf.hpp:64:59: warning: typedef 'T_alpha_val' locally defined but not used [-Wunused-local-typedefs]
#    64 |       typename partials_return_type<T_alpha>::type>::type T_alpha_val;
#       |                                                           ^~~~~~~~~~~
# In file included from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix.hpp:19,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:24,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp: In member function 'void boost::numeric::ublas::matrix_binary<E1, E2, F>::const_iterator1::increment(boost::numeric::ublas::sparse_bidirectional_iterator_tag)':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp:2224:17: warning: this 'if' clause does not guard... [-Wmisleading-indentation]
#  2224 |                 if (it2_ != it2_end_)
#       |                 ^~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/matrix_expression.hpp:2227:21: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the 'if'
#  2227 |                     if (it2_ != it2_end_) {
#       |                     ^~
# In file included from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/multi_array/multi_array_ref.hpp:32,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/multi_array.hpp:34,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/multi_array_adaption.hpp:29,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:61:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp: At global scope:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:180:45: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   180 |         : public boost::functional::detail::unary_function<typename unary_traits<Predicate>::argument_type,bool>
#       |                                             ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:214:45: warning: 'template<class _Arg1, class _Arg2, class _Result> struct std::binary_function' is deprecated [-Wdeprecated-declarations]
#   214 |         : public boost::functional::detail::binary_function<
#       |                                             ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:131:12: note: declared here
#   131 |     struct binary_function
#       |            ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:252:45: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   252 |         : public boost::functional::detail::unary_function<
#       |                                             ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:299:45: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   299 |         : public boost::functional::detail::unary_function<
#       |                                             ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:345:57: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   345 |     class mem_fun_t : public boost::functional::detail::unary_function<T*, S>
#       |                                                         ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:361:58: warning: 'template<class _Arg1, class _Arg2, class _Result> struct std::binary_function' is deprecated [-Wdeprecated-declarations]
#   361 |     class mem_fun1_t : public boost::functional::detail::binary_function<T*, A, S>
#       |                                                          ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:131:12: note: declared here
#   131 |     struct binary_function
#       |            ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:377:63: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   377 |     class const_mem_fun_t : public boost::functional::detail::unary_function<const T*, S>
#       |                                                               ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:393:64: warning: 'template<class _Arg1, class _Arg2, class _Result> struct std::binary_function' is deprecated [-Wdeprecated-declarations]
#   393 |     class const_mem_fun1_t : public boost::functional::detail::binary_function<const T*, A, S>
#       |                                                                ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:131:12: note: declared here
#   131 |     struct binary_function
#       |            ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:438:61: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   438 |     class mem_fun_ref_t : public boost::functional::detail::unary_function<T&, S>
#       |                                                             ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:454:62: warning: 'template<class _Arg1, class _Arg2, class _Result> struct std::binary_function' is deprecated [-Wdeprecated-declarations]
#   454 |     class mem_fun1_ref_t : public boost::functional::detail::binary_function<T&, A, S>
#       |                                                              ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:131:12: note: declared here
#   131 |     struct binary_function
#       |            ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:470:67: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   470 |     class const_mem_fun_ref_t : public boost::functional::detail::unary_function<const T&, S>
#       |                                                                   ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:487:68: warning: 'template<class _Arg1, class _Arg2, class _Result> struct std::binary_function' is deprecated [-Wdeprecated-declarations]
#   487 |     class const_mem_fun1_ref_t : public boost::functional::detail::binary_function<const T&, A, S>
#       |                                                                    ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:131:12: note: declared here
#   131 |     struct binary_function
#       |            ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:533:73: warning: 'template<class _Arg, class _Result> struct std::unary_function' is deprecated [-Wdeprecated-declarations]
#   533 |     class pointer_to_unary_function : public boost::functional::detail::unary_function<Arg,Result>
#       |                                                                         ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:117:12: note: declared here
#   117 |     struct unary_function
#       |            ^~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/functional.hpp:557:74: warning: 'template<class _Arg1, class _Arg2, class _Result> struct std::binary_function' is deprecated [-Wdeprecated-declarations]
#   557 |     class pointer_to_binary_function : public boost::functional::detail::binary_function<Arg1,Arg2,Result>
#       |                                                                          ^~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/stl_function.h:131:12: note: declared here
#   131 |     struct binary_function
#       |            ^~~~~~~~~~~~~~~
# In file included from /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp:847:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan_fit.hpp: In function 'int pystan::{anonymous}::command(pystan::StanArgs&, Model&, pystan::StanHolder&, const std::vector<long unsigned int>&, const std::vector<std::__cxx11::basic_string<char> >&, RNG_t&)':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan_fit.hpp:841:12: warning: 'template<class> class std::auto_ptr' is deprecated: use 'std::unique_ptr' instead [-Wdeprecated-declarations]
#   841 |       std::auto_ptr<stan::io::var_context> init_context_ptr;
#       |            ^~~~~~~~
# In file included from /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/memory:76,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/config/no_tr1/memory.hpp:21,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/smart_ptr/shared_ptr.hpp:23,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/shared_ptr.hpp:17,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/LDLT_factor.hpp:7,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/check_ldlt_factor.hpp:6,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:34:
# /home/nkgarg/miniconda3/x86_64-conda-linux-gnu/include/c++/12.2.0/bits/unique_ptr.h:64:28: note: declared here
#    64 |   template<typename> class auto_ptr;
#       |                            ^~~~~~~~
# In file included from /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp:849:
# /tmp/pystan_ypsd1oot/anon_model_a05259dcade68de9675d2ad9b1145f54.hpp: In member function 'void anon_model_a05259dcade68de9675d2ad9b1145f54_namespace::anon_model_a05259dcade68de9675d2ad9b1145f54::transform_inits(const stan::io::var_context&, std::vector<int>&, std::vector<double>&, std::ostream*) const':
# /tmp/pystan_ypsd1oot/anon_model_a05259dcade68de9675d2ad9b1145f54.hpp:106:24: warning: typedef 'local_scalar_t__' locally defined but not used [-Wunused-local-typedefs]
#   106 |         typedef double local_scalar_t__;
#       |                        ^~~~~~~~~~~~~~~~
# /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp: In function 'PyObject* __pyx_pf_71stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374_2_call_sampler(PyObject*, PyObject*, PyObject*, PyObject*)':
# /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpp:9618:30: warning: comparison of integer expressions of different signedness: 'Py_ssize_t' {aka 'long int'} and 'std::vector<std::__cxx11::basic_string<char> >::size_type' {aka 'long unsigned int'} [-Wsign-compare]
#  9618 |     __pyx_t_12 = ((__pyx_t_9 != __pyx_v_fitptr->param_names_oi().size()) != 0);
#       |                    ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4,
#                  from /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, -1>; SrcXprType = Eigen::Matrix<double, -1, -1>; Functor = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, -1>; SrcXprType = Eigen::Matrix<double, -1, -1>; Functor = Eigen::internal::assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, -1, -1>; Src = Eigen::Matrix<double, -1, -1>; Func = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/PlainObjectBase.h:728:41:   required from 'Derived& Eigen::PlainObjectBase<Derived>::_set_noalias(const Eigen::DenseBase<OtherDerived>&) [with OtherDerived = Eigen::Matrix<double, -1, -1>; Derived = Eigen::Matrix<double, -1, -1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/Matrix.h:278:27:   required from 'Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>::Matrix(Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>&&) [with _Scalar = double; int _Rows = -1; int _Cols = -1; int _Options = 0; int _MaxRows = -1; int _MaxCols = -1]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/cholesky_decompose.hpp:86:21:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
#    86 |     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#       |                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::Matrix<double, -1, 1>; Functor = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::Matrix<double, -1, 1>; Functor = Eigen::internal::assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::Matrix<double, -1, 1>; Func = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/PlainObjectBase.h:728:41:   required from 'Derived& Eigen::PlainObjectBase<Derived>::_set_noalias(const Eigen::DenseBase<OtherDerived>&) [with OtherDerived = Eigen::Matrix<double, -1, 1>; Derived = Eigen::Matrix<double, -1, 1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/Matrix.h:278:27:   required from 'Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>::Matrix(Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>&&) [with _Scalar = double; int _Rows = -1; int _Cols = 1; int _Options = 0; int _MaxRows = -1; int _MaxCols = 1]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/matrix_exp_action_handler.hpp:63:36:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::add_assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::add_assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::Matrix<double, -1, 1>; Functor = add_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::Matrix<double, -1, 1>; Functor = Eigen::internal::add_assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::Matrix<double, -1, 1>; Func = add_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:27:   required from 'void Eigen::internal::call_assignment(Dst&, const Src&, const Func&, typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::Matrix<double, -1, 1>; Func = add_assign_op<double, double>; typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type = void*; typename evaluator_traits<SrcXprType>::Shape = Eigen::DenseShape]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/CwiseBinaryOp.h:177:18:   required from 'Derived& Eigen::MatrixBase<Derived>::operator+=(const Eigen::MatrixBase<OtherDerived>&) [with OtherDerived = Eigen::Matrix<double, -1, 1>; Derived = Eigen::Matrix<double, -1, 1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/matrix_exp_action_handler.hpp:72:18:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1> > >, Eigen::internal::mul_assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1> > >, Eigen::internal::mul_assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::CwiseNullaryOp<scalar_constant_op<double>, Eigen::Matrix<double, -1, 1> >; Functor = mul_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, Eigen::Matrix<double, -1, 1> >; Functor = Eigen::internal::mul_assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::CwiseNullaryOp<scalar_constant_op<double>, Eigen::Matrix<double, -1, 1> >; Func = mul_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:27:   required from 'void Eigen::internal::call_assignment(Dst&, const Src&, const Func&, typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::CwiseNullaryOp<scalar_constant_op<double>, Eigen::Matrix<double, -1, 1> >; Func = mul_assign_op<double, double>; typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type = void*; typename evaluator_traits<SrcXprType>::Shape = Eigen::DenseShape]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/SelfCwiseBinaryOp.h:21:28:   required from 'Derived& Eigen::DenseBase<Derived>::operator*=(const Scalar&) [with Derived = Eigen::Matrix<double, -1, 1>; Scalar = double]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/matrix_exp_action_handler.hpp:80:14:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, 1, -1> >, Eigen::internal::evaluator<Eigen::Matrix<double, 1, -1> >, Eigen::internal::assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, 1, -1> >, Eigen::internal::evaluator<Eigen::Matrix<double, 1, -1> >, Eigen::internal::assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, 1, -1>; SrcXprType = Eigen::Matrix<double, 1, -1>; Functor = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, 1, -1>; SrcXprType = Eigen::Matrix<double, 1, -1>; Functor = Eigen::internal::assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, 1, -1>; Src = Eigen::Matrix<double, 1, -1>; Func = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/PlainObjectBase.h:728:41:   required from 'Derived& Eigen::PlainObjectBase<Derived>::_set_noalias(const Eigen::DenseBase<OtherDerived>&) [with OtherDerived = Eigen::Matrix<double, 1, -1>; Derived = Eigen::Matrix<double, 1, -1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/Matrix.h:278:27:   required from 'Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>::Matrix(Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>&&) [with _Scalar = double; int _Rows = 1; int _Cols = -1; int _Options = 1; int _MaxRows = 1; int _MaxCols = -1]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/to_row_vector.hpp:35:10:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > > >, Eigen::internal::add_assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > > >, Eigen::internal::add_assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::CwiseBinaryOp<scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > >; Functor = add_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, 1>; SrcXprType = Eigen::CwiseBinaryOp<Eigen::internal::scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > >; Functor = Eigen::internal::add_assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::CwiseBinaryOp<scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > >; Func = add_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:27:   required from 'void Eigen::internal::call_assignment(Dst&, const Src&, const Func&, typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type) [with Dst = Eigen::Matrix<double, -1, 1>; Src = Eigen::CwiseBinaryOp<scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > >; Func = add_assign_op<double, double>; typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type = void*; typename evaluator_traits<SrcXprType>::Shape = Eigen::DenseShape]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/CwiseBinaryOp.h:177:18:   required from 'Derived& Eigen::MatrixBase<Derived>::operator+=(const Eigen::MatrixBase<OtherDerived>&) [with OtherDerived = Eigen::CwiseBinaryOp<Eigen::internal::scalar_quotient_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, -1, 1> > >; Derived = Eigen::Matrix<double, -1, 1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/welford_covar_estimator.hpp:27:19:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::add_assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::evaluator<Eigen::Matrix<double, -1, -1> >, Eigen::internal::add_assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, -1>; SrcXprType = Eigen::Matrix<double, -1, -1>; Functor = add_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Matrix<double, -1, -1>; SrcXprType = Eigen::Matrix<double, -1, -1>; Functor = Eigen::internal::add_assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, -1, -1>; Src = Eigen::Matrix<double, -1, -1>; Func = add_assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:797:27:   required from 'void Eigen::internal::call_assignment(Dst&, const Src&, const Func&, typename enable_if<evaluator_assume_aliasing<Src>::value, void*>::type) [with Dst = Eigen::Matrix<double, -1, -1>; Src = Eigen::Product<Eigen::CwiseBinaryOp<scalar_difference_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::Matrix<double, -1, 1> >, Eigen::Transpose<Eigen::Matrix<double, -1, 1> >, 0>; Func = add_assign_op<double, double>; typename enable_if<evaluator_assume_aliasing<Src>::value, void*>::type = void*; typename evaluator_traits<SrcXprType>::Shape = Eigen::DenseShape]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/CwiseBinaryOp.h:177:18:   required from 'Derived& Eigen::MatrixBase<Derived>::operator+=(const Eigen::MatrixBase<OtherDerived>&) [with OtherDerived = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_difference_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::Matrix<double, -1, 1> >, Eigen::Transpose<Eigen::Matrix<double, -1, 1> >, 0>; Derived = Eigen::Matrix<double, -1, -1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/welford_covar_estimator.hpp:28:39:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseBinaryOp<Eigen::internal::scalar_difference_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::Matrix<double, -1, 1> > > >, Eigen::internal::add_assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Matrix<double, -1, 1> >, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::CwiseBinaryOp<Eigen::internal::scalar_difference_op<double, double>, const Eigen::Matrix<double, -1, 1>, const Eigen::Matrix<double, -1, 1> > > >, Eigen::internal::add_assign_op<double, double>, 0>'
# ...
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Matrix<double, 1, -1>; Src = Eigen::CwiseNullaryOp<scalar_constant_op<double>, Eigen::Matrix<double, 1, -1> >; Func = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:27:   required from 'void Eigen::internal::call_assignment(Dst&, const Src&, const Func&, typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type) [with Dst = Eigen::Matrix<double, 1, -1>; Src = Eigen::CwiseNullaryOp<scalar_constant_op<double>, Eigen::Matrix<double, 1, -1> >; Func = assign_op<double, double>; typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type = void*; typename evaluator_traits<SrcXprType>::Shape = Eigen::DenseShape]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:782:18:   [ skipping 17 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:245:64:   required from 'static void Eigen::internal::generic_product_impl<Lhs, Rhs, Eigen::DenseShape, Eigen::DenseShape, 6>::evalTo(Dst&, const Lhs&, const Rhs&) [with Dst = Eigen::Matrix<double, 1, 1, 0, 1, 1>; Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:124:75:   required from 'Eigen::internal::product_evaluator<Eigen::Product<Lhs, Rhs, Option>, ProductTag, LhsShape, RhsShape>::product_evaluator(const XprType&) [with Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>; int Options = 0; int ProductTag = 6; LhsShape = Eigen::DenseShape; RhsShape = Eigen::DenseShape; typename Eigen::internal::traits<typename Eigen::Product<Lhs, Rhs, Option>::Rhs>::Scalar = double; typename Eigen::Product<Lhs, Rhs, Option>::Rhs = Eigen::Matrix<double, -1, 1>; typename Eigen::internal::traits<typename Eigen::Product<Lhs, Rhs, Option>::Lhs>::Scalar = double; typename Eigen::Product<Lhs, Rhs, Option>::Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; XprType = Eigen::Product<Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>, Eigen::Matrix<double, -1, 1>, 0>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:35:70:   required from 'Eigen::internal::evaluator<Eigen::Product<Lhs, Rhs, Option> >::evaluator(const XprType&) [with Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>; int Options = 0; XprType = Eigen::Product<Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>, Eigen::Matrix<double, -1, 1>, 0>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/Product.h:132:22:   required from 'Eigen::internal::dense_product_base<Lhs, Rhs, Option, 6>::operator const Scalar() const [with Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>; int Option = 0; Scalar = double]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/src/stan/mcmc/hmc/hamiltonians/dense_e_metric.hpp:24:60:   required from 'double stan::mcmc::dense_e_metric<Model, BaseRNG>::T(stan::mcmc::dense_e_point&) [with Model = anon_model_a05259dcade68de9675d2ad9b1145f54_namespace::anon_model_a05259dcade68de9675d2ad9b1145f54; BaseRNG = boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399> >]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/src/stan/mcmc/hmc/hamiltonians/dense_e_metric.hpp:23:14:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h: In instantiation of 'struct Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1>, 0, Eigen::Stride<0, 0> > >, Eigen::internal::evaluator<Eigen::Transpose<const Eigen::Transpose<const Eigen::Matrix<double, -1, 1> > > >, Eigen::internal::assign_op<double, double> >':
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:49:   required from 'class Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::Map<Eigen::Matrix<double, -1, 1>, 0, Eigen::Stride<0, 0> > >, Eigen::internal::evaluator<Eigen::Transpose<const Eigen::Transpose<const Eigen::Matrix<double, -1, 1> > > >, Eigen::internal::assign_op<double, double>, 0>'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10:   required from 'void Eigen::internal::call_dense_assignment_loop(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Map<Eigen::Matrix<double, -1, 1>, 0, Eigen::Stride<0, 0> >; SrcXprType = Eigen::Transpose<const Eigen::Transpose<const Eigen::Matrix<double, -1, 1> > >; Functor = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:31:   required from 'static void Eigen::internal::Assignment<DstXprType, SrcXprType, Functor, Eigen::internal::Dense2Dense, Weak>::run(DstXprType&, const SrcXprType&, const Functor&) [with DstXprType = Eigen::Map<Eigen::Matrix<double, -1, 1>, 0, Eigen::Stride<0, 0> >; SrcXprType = Eigen::Transpose<const Eigen::Transpose<const Eigen::Matrix<double, -1, 1> > >; Functor = Eigen::internal::assign_op<double, double>; Weak = void]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:49:   required from 'void Eigen::internal::call_assignment_no_alias(Dst&, const Src&, const Func&) [with Dst = Eigen::Map<Eigen::Matrix<double, -1, 1>, 0, Eigen::Stride<0, 0> >; Src = Eigen::Transpose<const Eigen::Transpose<const Eigen::Matrix<double, -1, 1> > >; Func = assign_op<double, double>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:27:   required from 'void Eigen::internal::call_assignment(Dst&, const Src&, const Func&, typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type) [with Dst = Eigen::Map<Eigen::Matrix<double, -1, 1>, 0, Eigen::Stride<0, 0> >; Src = Eigen::Transpose<const Eigen::Transpose<const Eigen::Matrix<double, -1, 1> > >; Func = assign_op<double, double>; typename enable_if<(! evaluator_assume_aliasing<Src>::value), void*>::type = void*; typename evaluator_traits<SrcXprType>::Shape = Eigen::DenseShape]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:782:18:   [ skipping 18 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:245:64:   required from 'static void Eigen::internal::generic_product_impl<Lhs, Rhs, Eigen::DenseShape, Eigen::DenseShape, 6>::evalTo(Dst&, const Lhs&, const Rhs&) [with Dst = Eigen::Matrix<double, 1, 1, 0, 1, 1>; Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:124:75:   required from 'Eigen::internal::product_evaluator<Eigen::Product<Lhs, Rhs, Option>, ProductTag, LhsShape, RhsShape>::product_evaluator(const XprType&) [with Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>; int Options = 0; int ProductTag = 6; LhsShape = Eigen::DenseShape; RhsShape = Eigen::DenseShape; typename Eigen::internal::traits<typename Eigen::Product<Lhs, Rhs, Option>::Rhs>::Scalar = double; typename Eigen::Product<Lhs, Rhs, Option>::Rhs = Eigen::Matrix<double, -1, 1>; typename Eigen::internal::traits<typename Eigen::Product<Lhs, Rhs, Option>::Lhs>::Scalar = double; typename Eigen::Product<Lhs, Rhs, Option>::Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; XprType = Eigen::Product<Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>, Eigen::Matrix<double, -1, 1>, 0>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ProductEvaluators.h:35:70:   required from 'Eigen::internal::evaluator<Eigen::Product<Lhs, Rhs, Option> >::evaluator(const XprType&) [with Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>; int Options = 0; XprType = Eigen::Product<Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>, Eigen::Matrix<double, -1, 1>, 0>]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/Product.h:132:22:   required from 'Eigen::internal::dense_product_base<Lhs, Rhs, Option, 6>::operator const Scalar() const [with Lhs = Eigen::Product<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double, double>, const Eigen::CwiseNullaryOp<Eigen::internal::scalar_constant_op<double>, const Eigen::Matrix<double, 1, -1> >, const Eigen::Transpose<Eigen::Matrix<double, -1, 1> > >, Eigen::Matrix<double, -1, -1>, 0>; Rhs = Eigen::Matrix<double, -1, 1>; int Option = 0; Scalar = double]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/src/stan/mcmc/hmc/hamiltonians/dense_e_metric.hpp:24:60:   required from 'double stan::mcmc::dense_e_metric<Model, BaseRNG>::T(stan::mcmc::dense_e_point&) [with Model = anon_model_a05259dcade68de9675d2ad9b1145f54_namespace::anon_model_a05259dcade68de9675d2ad9b1145f54; BaseRNG = boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399> >]'
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/src/stan/mcmc/hmc/hamiltonians/dense_e_metric.hpp:23:14:   required from here
# /home/nkgarg/miniconda3/envs/ractest2/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: enum constant in boolean context [-Wint-in-bool-context]
# INFO:root:/home/nkgarg/miniconda3/bin/x86_64-conda-linux-gnu-c++ -shared -Wl,--allow-shlib-undefined -Wl,-rpath,/home/nkgarg/miniconda3/envs/ractest2/lib -Wl,-rpath-link,/home/nkgarg/miniconda3/envs/ractest2/lib -L/home/nkgarg/miniconda3/envs/ractest2/lib -Wl,--allow-shlib-undefined -Wl,-rpath,/home/nkgarg/miniconda3/envs/ractest2/lib -Wl,-rpath-link,/home/nkgarg/miniconda3/envs/ractest2/lib -L/home/nkgarg/miniconda3/envs/ractest2/lib -Wl,-O2 -Wl,--sort-common -Wl,--as-needed -Wl,-z,relro -Wl,-z,now -Wl,--disable-new-dtags -Wl,--gc-sections -Wl,--allow-shlib-undefined -Wl,-rpath,/home/nkgarg/miniconda3/lib -Wl,-rpath-link,/home/nkgarg/miniconda3/lib -L/home/nkgarg/miniconda3/lib -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/nkgarg/miniconda3/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/nkgarg/miniconda3/include /tmp/pystan_ypsd1oot/tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.o -o /tmp/pystan_ypsd1oot/stanfit4anon_model_a05259dcade68de9675d2ad9b1145f54_6433077372052408374.cpython-39-x86_64-linux-gnu.so
# lto-wrapper: warning: using serial compilation of 16 LTRANS jobs
# lto-wrapper: note: see the '-flto' option documentation for more information

# %%
fit = sm.sampling(data=stan_data, chains=2, warmup  = 150, iter= 250, n_jobs = 1)
# Out:
# Gradient evaluation took 6e-06 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 0.06 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 250 [  0%]  (Warmup)
# Iteration:  25 / 250 [ 10%]  (Warmup)
# Iteration:  50 / 250 [ 20%]  (Warmup)
# Iteration:  75 / 250 [ 30%]  (Warmup)
# Iteration: 100 / 250 [ 40%]  (Warmup)
# Iteration: 125 / 250 [ 50%]  (Warmup)
# Iteration: 150 / 250 [ 60%]  (Warmup)
# Iteration: 151 / 250 [ 60%]  (Sampling)
# Iteration: 175 / 250 [ 70%]  (Sampling)
# Iteration: 200 / 250 [ 80%]  (Sampling)
# Iteration: 225 / 250 [ 90%]  (Sampling)
# Iteration: 250 / 250 [100%]  (Sampling)
#
#  Elapsed Time: 0.000714 seconds (Warm-up)
#                0.000367 seconds (Sampling)
#                0.001081 seconds (Total)
#
#
# Gradient evaluation took 2e-06 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 0.02 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 250 [  0%]  (Warmup)
# Iteration:  25 / 250 [ 10%]  (Warmup)
# Iteration:  50 / 250 [ 20%]  (Warmup)
# Iteration:  75 / 250 [ 30%]  (Warmup)
# Iteration: 100 / 250 [ 40%]  (Warmup)
# Iteration: 125 / 250 [ 50%]  (Warmup)
# Iteration: 150 / 250 [ 60%]  (Warmup)
# Iteration: 151 / 250 [ 60%]  (Sampling)
# Iteration: 175 / 250 [ 70%]  (Sampling)
# Iteration: 200 / 250 [ 80%]  (Sampling)
# Iteration: 225 / 250 [ 90%]  (Sampling)
# Iteration: 250 / 250 [100%]  (Sampling)
#
#  Elapsed Time: 0.000655 seconds (Warm-up)
#                0.00035 seconds (Sampling)
#                0.001005 seconds (Total)

# %%
idata = az.from_pystan(posterior=fit, posterior_model=sm)

# %%
summary = az.summary(fit)

# %%
summary
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# theta  0.495  0.048   0.406    0.586      0.006    0.004      69.0      88.0
#
#        r_hat
# theta   1.05

# %%
# Stan gives us _samples_ for theta, representing P(\theta | data)
az.plot_posterior(idata)
# Out:
# <AxesSubplot: title={'center': 'theta'}>

# %%
sns.histplot(data=az.extract(fit), x='theta', kde=True)
# Out:
# <AxesSubplot: xlabel='theta', ylabel='Count'>

# %%
az.plot_trace(fit, compact=False, legend=True)
# Out:
# array([[<AxesSubplot: title={'center': 'theta'}>,
#         <AxesSubplot: title={'center': 'theta'}>]], dtype=object)
